# %%
using CSV
using DataFrames
using StatsPlots
using Dates
using Statistics
using MLJScientificTypes
using HypothesisTests
using StatsBase
using CategoricalArrays
default(fmt=:png)
gr()
# Out:
# Plots.GRBackend()

# %% [markdown]
# # Overview

# %%
df = CSV.read("superstore_dataset2011-2015.csv", DataFrame)
df = select(df, Not(["Row ID", "Order ID", "Customer Name", "Postal Code", "Product Name"]))
first(df, 5)
# Out:
# 5×19 DataFrame
#  Row │ Order Date  Ship Date  Ship Mode       Customer ID  Segment      City   ⋯
#      │ String      String     String          String       String       String ⋯
# ─────┼──────────────────────────────────────────────────────────────────────────
#    1 │ 1/1/2011    6/1/2011   Standard Class  TB-11280     Consumer     Consta ⋯
#    2 │ 1/1/2011    8/1/2011   Standard Class  JH-15985     Consumer     Wagga
#    3 │ 1/1/2011    5/1/2011   Second Class    AT-735       Consumer     Budape
#    4 │ 1/1/2011    5/1/2011   Second Class    EM-14140     Home Office  Stockh
#    5 │ 1/1/2011    8/1/2011   Standard Class  JH-15985     Consumer     Wagga  ⋯
#                                                               14 columns omitted

# %% [markdown]
# Standardize some field

# %%
df = let data = df
    # If this cell was ran before, return the data
    if "OrderDate" in names(data)
        return data
    end
    # Convert date string to real datetime, which is easier to process
    convertdate(datestring) = if occursin("/", datestring)
        Date(datestring, dateformat"dd/mm/yyyy")
    else
        Date(datestring, dateformat"dd-mm-yyyy")
    end
    OrderDate = map(convertdate, data[!, "Order Date"])
    ShipDate = map(convertdate, data[!, "Order Date"])
    data = select(data, Not(["Order Date", "Ship Date"]))
    data.OrderDate = OrderDate
    data.ShipDate = ShipDate
    data.Year = map(year, OrderDate)
    data.Month = map(month, OrderDate)
    data.Quater = map(quarterofyear, OrderDate)
    
    # Also rename some columns, remove weird character
    for name in names(data)
        rename!(data, name => replace(name, r"[-\s,./;']" => ""))
    end
    
    # Ordinal data
    shipmodes = ["Standard Class", "Second Class", "First Class", "Same Day"]
    orderpriorities = ["Medium", "High", "Critical", "Low"]
    foreach([:ShipMode => shipmodes, :OrderPriority => orderpriorities]) do (name, order)
        data[!, name] = map(datum -> findfirst(isequal(datum), order), data[!, name])
    end
    
    # Nominal data
    #   Segment       │ CategoricalValue{String, UInt32} │ Multiclass{3}     │
    # │ City          │ CategoricalValue{String, UInt32} │ Multiclass{3636}  │
    # │ State         │ CategoricalValue{String, UInt32} │ Multiclass{1094}  │
    # │ Country       │ CategoricalValue{String, UInt32} │ Multiclass{147}   │
    # │ Market        │ CategoricalValue{String, UInt32} │ Multiclass{7}     │
    # │ Region        │ CategoricalValue{String, UInt32} │ Multiclass{13}    │
    # │ ProductID     │ CategoricalValue{String, UInt32} │ Multiclass{10292} │
    # │ Category      │ CategoricalValue{String, UInt32} │ Multiclass{3}     │
    # │ SubCategory  
    foreach([:Segment, :City, :State, :Country, :Market, :Region, :Category, :SubCategory]) do name
        data[!, name] = categorical(data[!, name])
    end
    
    sort(data, :OrderDate)
end
first(df, 5)
# Out:
# 5×22 DataFrame
#  Row │ ShipMode  CustomerID  Segment      City         State            Countr ⋯
#      │ Int64     String      Cat…         Cat…         Cat…             Cat…   ⋯
# ─────┼──────────────────────────────────────────────────────────────────────────
#    1 │        1  TB-11280    Consumer     Constantine  Constantine      Algeri ⋯
#    2 │        1  JH-15985    Consumer     Wagga Wagga  New South Wales  Austra
#    3 │        2  AT-735      Consumer     Budapest     Budapest         Hungar
#    4 │        2  EM-14140    Home Office  Stockholm    Stockholm        Sweden
#    5 │        1  JH-15985    Consumer     Wagga Wagga  New South Wales  Austra ⋯
#                                                               17 columns omitted

# %%
schema(df)
# Out:
# ┌───────────────┬──────────────────────────────────┬──────────────────┐
# │ _.names       │ _.types                          │ _.scitypes       │
# ├───────────────┼──────────────────────────────────┼──────────────────┤
# │ ShipMode      │ Int64                            │ Count            │
# │ CustomerID    │ String                           │ Textual          │
# │ Segment       │ CategoricalValue{String, UInt32} │ Multiclass{3}    │
# │ City          │ CategoricalValue{String, UInt32} │ Multiclass{3636} │
# │ State         │ CategoricalValue{String, UInt32} │ Multiclass{1094} │
# │ Country       │ CategoricalValue{String, UInt32} │ Multiclass{147}  │
# │ Market        │ CategoricalValue{String, UInt32} │ Multiclass{7}    │
# │ Region        │ CategoricalValue{String, UInt32} │ Multiclass{13}   │
# │ ProductID     │ String                           │ Textual          │
# │ Category      │ CategoricalValue{String, UInt32} │ Multiclass{3}    │
# │ SubCategory   │ CategoricalValue{String, UInt32} │ Multiclass{17}   │
# │ Sales         │ Float64                          │ Continuous       │
# │ Quantity      │ Int64                            │ Count            │
# │ Discount      │ Float64                          │ Continuous       │
# │ Profit        │ Float64                          │ Continuous       │
# │ ShippingCost  │ Float64                          │ Continuous       │
# │ OrderPriority │ Int64                            │ Count            │
# │ OrderDate     │ Date                             │ ScientificDate   │
# │ ShipDate      │ Date                             │ ScientificDate   │
# │ Year          │ Int64                            │ Count            │
# │ Month         │ Int64                            │ Count            │
# │ Quater        │ Int64                            │ Count            │
# └───────────────┴──────────────────────────────────┴──────────────────┘
# _.nrows = 51290

# %%
sort(combine(groupby(df, [:ProductID, :Market]), :Quantity => sum), :Quantity_sum, rev = true)
# Out:
# 12401×3 DataFrame
#    Row │ ProductID         Market  Quantity_sum
#        │ String            Cat…    Int64
# ───────┼────────────────────────────────────────
#      1 │ OFF-AR-10003651   EU               143
#      2 │ OFF-BI-10002570   EU               102
#      3 │ OFF-AR-10000110   EU                97
#      4 │ OFF-ST-10004377   EU                89
#      5 │ OFF-AR-10004519   EU                86
#      6 │ OFF-BI-10001808   EU                84
#      7 │ OFF-AR-10003066   EU                84
#      8 │ OFF-BI-10003708   EU                83
#      9 │ OFF-AR-10001418   EU                81
#     10 │ OFF-AR-10001228   EU                80
#     11 │ OFF-ST-10001562   EU                79
#    ⋮   │        ⋮            ⋮          ⋮
#  12392 │ TEC-SHA-10000479  EMEA               1
#  12393 │ OFF-XER-10003329  Africa             1
#  12394 │ TEC-CO-10002065   APAC               1
#  12395 │ OFF-HAR-10000414  EMEA               1
#  12396 │ FUR-BAR-10001039  EMEA               1
#  12397 │ FUR-DEF-10000720  EMEA               1
#  12398 │ FUR-SAF-10000949  EMEA               1
#  12399 │ FUR-TA-10002557   EU                 1
#  12400 │ TEC-MEM-10001163  EMEA               1
#  12401 │ TEC-CAN-10004291  Africa             1
#                               12380 rows omitted

# %%
let df_by_year = groupby(df, :Year), attr_to_plot = :Profit
    n = length(df_by_year)
    p = plot(layout=n)
    ymax = maximum(df[!, attr_to_plot])
    ymin = minimum(df[!, attr_to_plot])
    for (i, df) in enumerate(df_by_year)
        plot!(p, df.OrderDate, df[!, attr_to_plot], 
            subplot=n-i+1,
            label=false,
            xrotation=30,
            ylims=(ymin, ymax),
            yformatter=identity
        )
    end
    p
end

# %%
let df_by_year = groupby(df, :Year)
    n = length(df_by_year)
    p = plot(layout=n)
    ymax = maximum(df.Sales)
    ymin = minimum(df.Sales)
    for (i, df) in enumerate(df_by_year)
        plot!(p, df.OrderDate, df.Sales, 
            subplot=n-i+1,
            label=false,
            xrotation=30,
            ylims=(ymin, ymax),
            yformatter=identity
        )
    end
    p
end

# %%
simple_matching(df.Category)
# Out:
# Dict{CategoricalValue{String, UInt32}, Float32} with 3 entries:
#   "Furniture"       => 0.807448
#   "Technology"      => 0.802281
#   "Office Supplies" => 0.390271

# %%
function simple_matching(X)
    cX = countmap(X)
    n = length(X)
    result = Dict{eltype(X), Float32}()
    for (key, val) in cX
        result[key] = (n - cX[key]) / n
    end
    result
end
# Out:
# simple_matching (generic function with 2 methods)

# %%
eltype(df.Category)
# Out:
# CategoricalValue{String, UInt32}
